# %% [markdown]
# # Customer Service Request Analysis
# <img src=https://data.folio3.com/wp-content/uploads/2025/08/Customer-Service-Data-Analytics-Strategies-1024x682.png>

# %% [markdown]
# ## 1.1 Import the Libraries

# %%
# Customer Service Request Analysis
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.2 Visualize the dataset

# %%
# Load Dataset
df = pd.read_csv(
    r"C:\Users\pradn\Downloads\311-service-requests-nyc\311_Service_Requests_from_2010_to_Present.csv",
    low_memory=False
)
df.head(53)
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1     32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2     32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3     32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4     32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# 5     32306554  12/31/2015 11:56:30 PM  01/01/2016 01:50:11 AM   NYPD
# 6     32306559  12/31/2015 11:55:32 PM  01/01/2016 01:53:54 AM   NYPD
# 7     32307009  12/31/2015 11:54:05 PM  01/01/2016 01:42:54 AM   NYPD
# 8     32308581  12/31/2015 11:53:58 PM  01/01/2016 08:27:32 AM   NYPD
# 9     32308391  12/31/2015 11:53:58 PM  01/01/2016 01:17:40 AM   NYPD
# 10    32305071  12/31/2015 11:52:58 PM  01/01/2016 07:41:38 AM   NYPD
# 11    32306260  12/31/2015 11:50:57 PM  01/01/2016 10:58:08 AM   NYPD
# ...

# %% [markdown]
# ## 1.3  Print the columns of the DataFrame

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:57   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:03   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:13   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:42   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %% [markdown]
# ## 1.4 Identify the shape of the dataset

# %%
df.shape
# Out:
# (364558, 53)

# %%
# Display column names
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  object
#  2   Closed Date                     362177 non-null  object
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
#  11  Cross Street 1                  307370 non-null  object
# ...

# %%
df.tail(10)
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 364548    29613386  01/01/2015 12:08:34 AM  01/01/2015 02:42:23 AM   NYPD
# 364549    29610965  01/01/2015 12:08:02 AM  01/01/2015 01:17:43 AM   NYPD
# 364550    29610950  01/01/2015 12:06:43 AM  01/01/2015 06:05:18 AM   NYPD
# 364551    29607567  01/01/2015 12:06:02 AM  01/01/2015 12:43:41 AM   NYPD
# 364552    29610051  01/01/2015 12:05:05 AM  01/01/2015 01:22:10 AM   NYPD
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# 364555    29607589  01/01/2015 12:01:30 AM  01/01/2015 12:20:33 AM   NYPD
# 364556    29610889  01/01/2015 12:01:29 AM  01/01/2015 02:42:22 AM   NYPD
# 364557    29611816  01/01/2015 12:00:50 AM  01/01/2015 02:47:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 364548  New York City Police Department         Blocked Driveway
# ...

# %%
df.sample(10)
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 323324    30068943  03/01/2015 11:18:24 AM  03/01/2015 01:48:46 PM   NYPD
# 231616    30766192  06/03/2015 11:08:07 PM  06/03/2015 11:21:47 PM   NYPD
# 4890      32275097  12/26/2015 09:41:26 AM  12/26/2015 12:52:20 PM   NYPD
# 109520    31559082  09/18/2015 10:02:02 AM  09/18/2015 04:38:11 PM   NYPD
# 47466     31972923  11/13/2015 11:19:43 PM  11/14/2015 01:20:20 AM   NYPD
# 76646     31777814  10/17/2015 12:27:09 PM  10/17/2015 02:52:29 PM   NYPD
# 17493     32195592  12/13/2015 02:47:22 AM  12/13/2015 12:03:21 PM   NYPD
# 163719    31213195  08/01/2015 01:44:20 PM  08/01/2015 04:23:33 PM   NYPD
# 32664     32083539  11/28/2015 08:35:26 PM  11/28/2015 10:14:57 PM   NYPD
# 5917      32267871  12/24/2015 11:46:28 PM  12/25/2015 10:16:01 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 323324  New York City Police Department         Blocked Driveway
# ...

# %% [markdown]
# # Data types of all columns

# %%
# Data types of all columns
df.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# ...

# %% [markdown]
# # Summary statistics

# %%
# Summary statistics
df.describe()
# Out:
#          Unique Key   Incident Zip  X Coordinate (State Plane)  \
# count  3.645580e+05  361560.000000                3.605280e+05
# mean   3.106595e+07   10858.496659                1.005043e+06
# std    7.331531e+05     578.263114                2.196362e+04
# min    2.960737e+07      83.000000                9.133570e+05
# 25%    3.049938e+07   10314.000000                9.919460e+05
# 50%    3.108795e+07   11209.000000                1.003470e+06
# 75%    3.167433e+07   11238.000000                1.019134e+06
# max    3.231065e+07   11697.000000                1.067186e+06
#
#        Y Coordinate (State Plane)  School or Citywide Complaint  Vehicle Type  \
# count               360528.000000                           0.0           0.0
# mean                203425.305782                           NaN           NaN
# std                  29842.192857                           NaN           NaN
# min                 121185.000000                           NaN           NaN
# ...

# %% [markdown]
# # Task 1.5 : Identify Variables with Null Values

# %%
df.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2381
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6501
# Location Type                        133
# Incident Zip                        2998
# Incident Address                   51699
# Street Name                        51699
# Cross Street 1                     57188
# Cross Street 2                     57805
# Intersection Street 1             313438
# Intersection Street 2             314046
# Address Type                        3252
# City                                2997
# Landmark                          364183
# Facility Type                       2389
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2402
# ...

# %% [markdown]
# ### Observation:
# • Some columns contain a large number of missing values.
#
# • Closed Date has 2381 missing values.
#
# • City has 2997 missing values.
#
# • Descriptor has 6501 missing values.
#
# • Columns like Vehicle Type, Landmark, Ferry Direction, and Garage Lot Name have a very high number of missing values because they are applicable only to specific complaint types.

# %% [markdown]
# # Task 2.1 : Frequency Plot of Null Values

# %%
null_values = df.isnull().sum()

plt.figure(figsize=(18,6))
null_values.plot(kind='bar', color='skyblue')

plt.title("Number of Null Values in Each Column")
plt.xlabel("Columns")
plt.ylabel("Number of Null Values")

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # 2.2 Check missing values in Closed Date

# %%
df['Closed Date'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 2.2.1 Remove rows with null Closed Date

# %%
df = df.dropna(subset=['Closed Date'])

# %% [markdown]
# # Verify that null values are removed

# %%
# Verify that null values are removed
df['Closed Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
# New shape after removing rows

df.shape
# Out:
# (362177, 53)

# %% [markdown]
# # Observation:
# 1. The dataset originally contained 364,558 records.
# 2. After removing records with missing 'Closed Date' values,
# 3. 2,381 records were removed.
# 4. The cleaned dataset now contains 362,177 records and 53 columns.

# %% [markdown]
# # 2.3.2 Convert Created Date and Closed Date into datetime format

# %%
df['Created Date'].head()
# Out:
# 0    12/31/2015 11:59:45 PM
# 1    12/31/2015 11:59:44 PM
# 2    12/31/2015 11:59:29 PM
# 3    12/31/2015 11:57:46 PM
# 4    12/31/2015 11:56:58 PM
# Name: Created Date, dtype: object

# %%
df[['Created Date', 'Closed Date', 'Request_Closing_Time']].head()
# Out:
#          Created Date         Closed Date  Request_Closing_Time
# 0 2015-12-31 23:59:45 2016-01-01 00:55:15                3330.0
# 1 2015-12-31 23:59:44 2016-01-01 01:26:57                5233.0
# 2 2015-12-31 23:59:29 2016-01-01 04:51:03               17494.0
# 3 2015-12-31 23:57:46 2016-01-01 07:43:13               27927.0
# 4 2015-12-31 23:56:58 2016-01-01 03:24:42               12464.0

# %%
df['Created Date'].head(10)
# Out:
# 0   2015-12-31 23:59:45
# 1   2015-12-31 23:59:44
# 2   2015-12-31 23:59:29
# 3   2015-12-31 23:57:46
# 4   2015-12-31 23:56:58
# 5   2015-12-31 23:56:30
# 6   2015-12-31 23:55:32
# 7   2015-12-31 23:54:05
# 8   2015-12-31 23:53:58
# 9   2015-12-31 23:53:58
# Name: Created Date, dtype: datetime64[ns]

# %%
df[['Created Date','Closed Date']].head()
# Out:
#              Created Date             Closed Date
# 0  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM
# 1  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM
# 2  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM
# 3  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM
# 4  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM

# %%
print(df[['Created Date', 'Closed Date', 'Request_Closing_Time']].dtypes)
# Out:
# Created Date            datetime64[ns]
# Closed Date             datetime64[ns]
# Request_Closing_Time           float64
# dtype: object

# %%
print(df['Request_Closing_Time'].dtype)
# Out:
# timedelta64[ns]

# %%
df['Request_Closing_Time'].describe()
# Out:
# count    3.621770e+05
# mean     1.511330e+04
# std      2.110255e+04
# min      6.100000e+01
# 25%      4.533000e+03
# 50%      9.616000e+03
# 75%      1.887800e+04
# max      2.134342e+06
# Name: Request_Closing_Time, dtype: float64

# %%
print(df['Request_Closing_Time'].dtype)
# Out:
# float64

# %% [markdown]
# ## Complaint Type and City:

# %%
df[['Complaint Type', 'City']].isnull().sum()
# Out:
# Complaint Type       0
# City              2997
# dtype: int64

# %%
df[['Complaint Type', 'City']].isnull().sum()
# Out:
# Complaint Type    0
# City              0
# dtype: int64

# %% [markdown]
# ### 2.2 Draw a frequency plot for complaints in each city

# %%
plt.figure(figsize=(12,8))
sns.countplot(y='City', data=df, order=df['City'].value_counts().index)
plt.title('Complaints in Each City', fontsize=16, fontname='Times New Roman')
plt.xlabel('Count', fontsize=12, fontname='Times New Roman')
plt.ylabel('City', fontsize=12, fontname='Times New Roman')
plt.show()

# %% [markdown]
# ## 2.3.7 Scatter Plot for Brooklyn

# %%
brooklyn = df[df['City']=='BROOKLYN']
plt.scatter(brooklyn['Longitude'], brooklyn['Latitude'], color='skyblue')
plt.title('Brooklyn Complaints', fontsize=16, fontname='Times New Roman')
plt.xlabel('Longitude', fontsize=12, fontname='Times New Roman')
plt.ylabel('Latitude', fontsize=12, fontname='Times New Roman')
plt.show()

# %% [markdown]
# ## Hexbin plot of the concentration of complaints across Brooklyn

# %%
plt.hexbin(brooklyn['Longitude'], brooklyn['Latitude'], gridsize=30, cmap='Blues')
plt.colorbar(label='Count')
plt.title('Complaint Density in Brooklyn', fontsize=16, fontname='Times New Roman')
plt.xlabel('Longitude', fontsize=12, fontname='Times New Roman')
plt.ylabel('Latitude', fontsize=12, fontname='Times New Roman')
plt.show()

# %% [markdown]
# ## 3.1 Plot a bar graph to show the types of complaints

# %%
plt.figure(figsize=(12,8))
sns.countplot(y='Complaint Type', data=df, order=df['Complaint Type'].value_counts().index)
plt.title('Complaint Types', fontsize=16, fontname='Times New Roman')
plt.xlabel('Count', fontsize=12, fontname='Times New Roman')
plt.ylabel('Complaint Type', fontsize=12, fontname='Times New Roman')
plt.show()

# %% [markdown]
# ## 3.2 Check the frequency of various types of complaints for New York City

# %%
ny = df[df['City'] == 'NEW YORK']
ny['Complaint Type'].value_counts()
# Out:
# Complaint Type
# Noise - Street/Sidewalk      22252
# Noise - Commercial           18692
# Illegal Parking              14553
# Noise - Vehicle               6295
# Homeless Encampment           3060
# Blocked Driveway              2707
# Vending                       2639
# Animal Abuse                  1941
# Traffic                       1770
# Noise - Park                  1244
# Derelict Vehicle               695
# Drinking                       321
# Urinating in Public            264
# Bike/Roller/Skate Chronic      254
# Noise - House of Worship       222
# Panhandling                    206
# Disorderly Youth                81
# Posting Advertisement           49
# Illegal Fireworks               38
# Graffiti                        25
# Squeegee                         4
# Name: count, dtype: int64

# %% [markdown]
# ## 3.3 Find the top 10 complaint types

# %%
top10 = df['Complaint Type'].value_counts().head(10)
print(top10)
# Out:
# Complaint Type
# Blocked Driveway           100881
# Illegal Parking             92679
# Noise - Street/Sidewalk     51692
# Noise - Commercial          44109
# Derelict Vehicle            21661
# Noise - Vehicle             19352
# Animal Abuse                10541
# Traffic                      5198
# Homeless Encampment          4879
# Vending                      4192
# Name: count, dtype: int64

# %% [markdown]
# ##  Top 10 Complaints Types Graph

# %%
top10.plot(kind='bar', figsize=(10,5), color='skyblue')
plt.title('Top 10 Complaint Types', fontsize=16, fontname='Times New Roman')
plt.xlabel('Complaint Type', fontsize=12, fontname='Arial')
plt.ylabel('Count', fontsize=12, fontname='Arial')
plt.show()

# %% [markdown]
# ## 3.4 Display the various types of complaints in each city

# %%
pd.crosstab(df['City'], df['Complaint Type'])
# Out:
# Complaint Type       Agency Issues  Animal Abuse  Animal in a Park  \
# City
# ARVERNE                          0            46                 0
# ASTORIA                          0           170                 0
# Astoria                          0             0                 0
# BAYSIDE                          0            53                 0
# BELLEROSE                        0            15                 0
# BREEZY POINT                     0             2                 0
# BRONX                            0          1971                 0
# BROOKLYN                         0          3191                 0
# CAMBRIA HEIGHTS                  0            15                 0
# CENTRAL PARK                     0             0                 0
# COLLEGE POINT                    0            35                 0
# CORONA                           0           104                 0
# EAST ELMHURST                    0            85                 0
# ...

# %% [markdown]
# ## 3.5 Create DataFrame df_new

# %%
df_new = pd.crosstab(df['Complaint Type'], df['City'])
df_new.head()
# Out:
# City                       ARVERNE  ASTORIA  Astoria  BAYSIDE  BELLEROSE  \
# Complaint Type
# Agency Issues                    0        0        0        0          0
# Animal Abuse                    46      170        0       53         15
# Animal in a Park                 0        0        0        0          0
# Bike/Roller/Skate Chronic        0       16        0        0          1
# Blocked Driveway                50     3436      159      514        138
#
# City                       BREEZY POINT  BRONX  BROOKLYN  CAMBRIA HEIGHTS  \
# Complaint Type
# Agency Issues                         0      0         0                0
# Animal Abuse                          2   1971      3191               15
# Animal in a Park                      0      0         0                0
# Bike/Roller/Skate Chronic             0     22       124                0
# Blocked Driveway                      3  17063     36447              177
#
# ...

# %% [markdown]
# ## 4.1 Show complaint types in each city (Stacked Bar Chart)

# %%
df_new.plot(kind='bar', stacked=True, figsize=(15,8))
plt.title('Complaint Types by City', fontsize=16, fontname='Times New Roman')
plt.xlabel('Complaint Type', fontsize=12, fontname='Times New Roman')
plt.ylabel('Count', fontsize=12, fontname='Times New Roman')
plt.show()

# %% [markdown]
# #  4.2 Sort complaint types based on average Request_Closing_Time

# %%
avg_time = df.groupby('Complaint Type')['Request_Closing_Time'].mean().sort_values()
avg_time
# Out:
# Complaint Type
# Posting Advertisement        7.286256e+03
# Illegal Fireworks            1.011348e+04
# Noise - Commercial           1.108576e+04
# Noise - House of Worship     1.139109e+04
# Noise - Park                 1.222606e+04
# Noise - Street/Sidewalk      1.223130e+04
# Traffic                      1.230912e+04
# Disorderly Youth             1.236375e+04
# Noise - Vehicle              1.256180e+04
# Urinating in Public          1.295929e+04
# Bike/Roller/Skate Chronic    1.312369e+04
# Drinking                     1.382130e+04
# Vending                      1.436628e+04
# Squeegee                     1.456025e+04
# Homeless Encampment          1.545138e+04
# Illegal Parking              1.565044e+04
# Panhandling                  1.585355e+04
# Blocked Driveway             1.623252e+04
# Animal Abuse                 1.803256e+04
# Agency Issues                1.828912e+04
# Graffiti                     2.327634e+04
# Derelict Vehicle             2.535960e+04
# ...

# %% [markdown]
# ## 5.1 Visualize the average Request_Closing_Time

# %%
avg_time = df.groupby('Complaint Type')['Request_Closing_Time'].mean().sort_values()

plt.figure(figsize=(12,8))
avg_time.plot(kind='barh', color='skyblue')
plt.title('Average Request Closing Time', fontsize=16, fontname='Times New Roman')
plt.xlabel('Time (Seconds)', fontsize=12, fontname='Times New Roman')
plt.ylabel('Complaint Type', fontsize=12, fontname='Times New Roman')
plt.show()

# %% [markdown]
# ## 6. Identify the significant variables by performing statistical analysis using p-values (ANOVA Test)

# %%
# !pip install scipy

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.15.3

# %%
from scipy.stats import f_oneway

groups = [group['Request_Closing_Time'].dropna() for name, group in df.groupby('Complaint Type')]

f_stat, p_value = f_oneway(*groups)

print("F-Statistic:", f_stat)
print("P-Value:", p_value)
# Out:
# F-Statistic: 565.2615700417628
# P-Value: 0.0

# %% [markdown]
# ## Task 7: Kruskal-Wallis H Test

# %%
from scipy.stats import kruskal

groups = [g['Request_Closing_Time'].dropna() for _, g in df_anova.groupby('Complaint Type')]

stat, p = kruskal(*groups)

print("H-Statistic:", stat)
print("P-Value:", p)
# Out:
# H-Statistic: 11985.335740628261
# P-Value: 0.0

# %%
if p < 0.05:
    print("Reject H0: One or more sample distributions are not equal")
else:
    print("Fail to reject H0: All sample distributions are equal")
# Out:
# Reject H0: One or more sample distributions are not equal

# %% [markdown]
#  ## 8: Observations
# 1. Missing values were identified and treated successfully.
# 2. Records with missing Closed Date were removed.
# 3. The City column was filled with "Unknown City" where values were missing.
# 4. New York and Brooklyn reported the highest number of complaints.
# 5. Noise Complaint, Illegal Parking, and Blocked Driveway were among the most frequent complaint types.
# 6. The average request closing time varies across complaint types.
# 7. The ANOVA test produced F = 433.57 and p-value = 0.0, indicating a statistically significant difference in average response times among complaint types.
# 8. The Kruskal-Wallis test can be used to confirm this result without assuming a normal distribution.
